# %%
import json 
import pandas as pd 
import requests
from pprint import pprint
from NameDataModule import GetPopularMovies

# %%
popular_movies_df = GetPopularMovies()

# %%
popular_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5580 entries, 0 to 5579
# Data columns (total 14 columns):
# adult                5580 non-null bool
# backdrop_path        5486 non-null object
# genre_ids            5580 non-null object
# id                   5580 non-null int64
# original_language    5580 non-null object
# original_title       5580 non-null object
# overview             5580 non-null object
# popularity           5580 non-null float64
# poster_path          5568 non-null object
# release_date         5575 non-null object
# title                5580 non-null object
# video                5580 non-null bool
# vote_average         5580 non-null float64
# vote_count           5580 non-null int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 534.1+ KB

# %%
top20_movies2019 = popular_movies_df.loc[popular_movies_df['release_date'].str.contains('2019')==True]
top20_movies2019en = top20_movies2019[top20_movies2019['original_language']=='en']
top20_movies2019en.head(21)
# Out:
#     adult                     backdrop_path                       genre_ids  \
# 0   False  /n6bUvigpRFqSwmPp1m2YADdbRBc.jpg                    [80, 18, 53]
# 1   False  /rtf4vjjLZLalpOzDUi0Qd2GTUqq.jpg                       [28, 878]
# 2   False  /nRXO2SnOA75OsWhNhXstHB8ZmI3.jpg                    [12, 16, 18]
# 3   False  /skvI4rYFrKXS73BJxWGH54Omlvv.jpg                 [12, 14, 10751]
# 4   False  /qAhedRxRYWZAgZ8O8pHIl6QHdD7.jpg                    [28, 12, 35]
# 7   False  /1nm0sk8UUx9jHCTHuMKe2jkt4Pn.jpg                            [27]
# 8   False  /oMAhce30UvkgJwlzMwsuLaPJ5cG.jpg                 [18, 36, 10752]
# 9   False  /rVqY0Bo4Npf6EIONUROxjYAJfmD.jpg      [12, 35, 14, 10749, 10751]
# 10  False  /5myQbDzw3l8K9yofUXRJ4UTVgam.jpg                   [28, 12, 878]
# 11  False  /cjRUhKyt2Jo3V1KNzc5tpPNfccG.jpg                   [28, 12, 878]
# 13  False  /3uG3aOhEzFCjcQulsJQiAzLSrw8.jpg                    [12, 27, 53]
# ...

# %%
top20_movies2019en = top20_movies2019en.sort_values('popularity', ascending=False).head(20)

# %%
print(top20_movies2019en['title'])
# Out:
# 0                                     Joker
# 1                     Terminator: Dark Fate
# 2                             The Lion King
# 3              Maleficent: Mistress of Evil
# 4     Fast & Furious Presents: Hobbs & Shaw
# 7                              Doctor Sleep
# 10                Spider-Man: Far from Home
# 11                             Dark Phoenix
# 23           Red Shoes and the Seven Dwarfs
# 8                                  The King
# 9                                   Aladdin
# 14          El Camino: A Breaking Bad Movie
# 15                                Good Boys
# 16                                Frozen II
# 13                  47 Meters Down: Uncaged
# 17                               Gemini Man
# 18                           It Chapter Two
# 19                   Zombieland: Double Tap
# 20           Dora and the Lost City of Gold
# 24                              Toy Story 4
# Name: title, dtype: object

# %%
# top20_movies2019_tconst = ['tt7286456','tt6450804', 'tt6105098', 'tt4777008', 'tt6806448', 'tt9430698', 'tt5606664', 'tt6320628', 'tt6565702', 'tt7984766', 'tt6139732', 'tt9243946', 'tt7343762', 'tt4520988', 'tt7329656', 'tt1025100', 'tt7349950', 'tt1560220']
# top20_movies2019['tconst'] = top20_movies2019_tconst
# top20_movies2019
# Out:
#     adult                     backdrop_path                       genre_ids  \
# 0   False  /n6bUvigpRFqSwmPp1m2YADdbRBc.jpg                    [80, 18, 53]
# 1   False  /rtf4vjjLZLalpOzDUi0Qd2GTUqq.jpg                       [28, 878]
# 2   False  /nRXO2SnOA75OsWhNhXstHB8ZmI3.jpg                    [12, 16, 18]
# 3   False  /skvI4rYFrKXS73BJxWGH54Omlvv.jpg                 [12, 14, 10751]
# 4   False  /qAhedRxRYWZAgZ8O8pHIl6QHdD7.jpg                    [28, 12, 35]
# 6   False  /iGnCzXEx0cFlUbpyAMeHwHWhPhx.jpg                    [28, 12, 16]
# 7   False  /1nm0sk8UUx9jHCTHuMKe2jkt4Pn.jpg                            [27]
# 10  False  /5myQbDzw3l8K9yofUXRJ4UTVgam.jpg                   [28, 12, 878]
# 11  False  /cjRUhKyt2Jo3V1KNzc5tpPNfccG.jpg                   [28, 12, 878]
# 8   False  /r0AWsZ9dBvC2No3kND9nxv3iRbb.jpg                 [18, 36, 10752]
# 9   False  /rVqY0Bo4Npf6EIONUROxjYAJfmD.jpg      [12, 35, 14, 10749, 10751]
# ...

# %%
top20_movies2019 = top20_movies2019.drop(columns=['adult','backdrop_path','genre_ids','overview','poster_path','video'])

# %%
top20_movies2019['title']
# Out:
#         id original_language                         original_title  \
# 0   475557                en                                  Joker
# 1   290859                en                  Terminator: Dark Fate
# 2   420818                en                          The Lion King
# 3   420809                en           Maleficent: Mistress of Evil
# 4   384018                en  Fast & Furious Presents: Hobbs & Shaw
# 6   568012                ja                            ワンピーススタンピード
# 7   501170                en                           Doctor Sleep
# 10  429617                en              Spider-Man: Far from Home
# 11  320288                en                           Dark Phoenix
# 8   504949                en                               The King
# 9   420817                en                                Aladdin
# 14  559969                en        El Camino: A Breaking Bad Movie
# 15  521777                en                              Good Boys
# ...

# %%
top20_movies2018 = popular_movies_df.loc[popular_movies_df['release_date'].str.contains('2018')==True]
top20_movies2018 = top20_movies2018.sort_values('popularity', ascending=False)
top20_movies2018.head()
# Out:
#     adult                     backdrop_path              genre_ids      id  \
# 12  False  /bOGkgRGdhrBYJSLpXaxhXVstddV.jpg          [28, 12, 878]  299536
# 27  False  /uUiId6cG32JSRI6RyBQSvQtLjz2.jpg  [28, 12, 16, 35, 878]  324857
# 49  False   /VuukZLgaCrho2Ar8Scl9HtV3yD.jpg              [28, 878]  335983
# 77  False  /17nDJQsGVim6oows2TlN98UacbO.jpg          [28, 12, 878]  424783
# 33  False  /93xA62uLd5CwMOAs37eQ7vPc1iV.jpg            [18, 10402]  424694
#
#    original_language                     original_title  \
# 12                en             Avengers: Infinity War
# 27                en  Spider-Man: Into the Spider-Verse
# 49                en                              Venom
# 77                en                          Bumblebee
# 33                en                  Bohemian Rhapsody
#
#                                              overview  popularity  \
# 12  As the Avengers and their allies have continue...     101.583
# ...

# %%
print(top20_movies2018['title'])
# Out:
# 12    Avengers: Infinity War
# Name: title, dtype: object

# %%
tv_url = 'https://api.themoviedb.org/3/tv/popular?api_key=6740709218b69a4e877ef5015c2bcd5d&language=en-US&page=1'

# %%
response2 = requests.get(tv_url).json()

# %%
pprint(response2)
# Out:
# {'page': 1,
#  'results': [{'backdrop_path': '/o9OKe3M06QMLOzTl3l6GStYtnE9.jpg',
#               'first_air_date': '2005-09-13',
#               'genre_ids': [18, 9648, 10765],
#               'id': 1622,
#               'name': 'Supernatural',
#               'origin_country': ['US'],
#               'original_language': 'en',
#               'original_name': 'Supernatural',
#               'overview': 'When they were boys, Sam and Dean Winchester lost '
#                           'their mother to a mysterious and demonic '
#                           'supernatural force. Subsequently, their father '
#                           'raised them to be soldiers. He taught them about '
#                           'the paranormal evil that lives in the dark corners '
#                           'and on the back roads of America ... and he taught '
#                           'them how to kill it. Now, the Winchester brothers '
# ...

# %%
results2 = response2['results']

# %%
popular_tv_df = pd.DataFrame(results2)
popular_tv_df.head()
# Out:
#                       backdrop_path first_air_date              genre_ids  \
# 0  /o9OKe3M06QMLOzTl3l6GStYtnE9.jpg     2005-09-13      [18, 9648, 10765]
# 1  /9yKCJTOh9m3Lol2RY3kw99QPH6x.jpg     2019-11-03            [18, 10765]
# 2  /7r4FieFH6Eh6S55hi8c9LOiFENg.jpg     2015-08-23               [18, 27]
# 3  /dXTyVDTIgeByvUOUEiHjbi8xX9A.jpg     2012-10-10  [80, 18, 9648, 10759]
# 4  /6ZdQTBy20HzWudZthAV7NkZWfIb.jpg     2014-10-07            [18, 10765]
#
#       id                   name origin_country original_language  \
# 0   1622           Supernatural           [US]                en
# 1  68507     His Dark Materials           [GB]                en
# 2  62286  Fear the Walking Dead           [US]                en
# 3   1412                  Arrow           [US]                en
# 4  60735              The Flash           [US]                en
#
#            original_name                                           overview  \
# ...

# %%
print(popular_tv_df['original_name'])
# Out:
# 0                          Supernatural
# 1                    His Dark Materials
# 2                 Fear the Walking Dead
# 3                                 Arrow
# 4                             The Flash
# 5                                   See
# 6                          The Simpsons
# 7                              4 Blocks
# 8                             Riverdale
# 9                        Grey's Anatomy
# 10                       Rick and Morty
# 11                           Family Guy
# 12    Law & Order: Special Victims Unit
# 13                           South Park
# 14                    NCIS: Los Angeles
# 15                            ハンターｘハンター
# 16         The End of the F***ing World
# 17                             Legacies
# 18                               Gotham
# 19                             Batwoman
# Name: original_name, dtype: object

# %%
top20_tv = popular_tv_df.sort_values('popularity', ascending=False).head(21)
top20_tv.head()
# Out:
#                       backdrop_path first_air_date              genre_ids  \
# 0  /o9OKe3M06QMLOzTl3l6GStYtnE9.jpg     2005-09-13      [18, 9648, 10765]
# 1  /9yKCJTOh9m3Lol2RY3kw99QPH6x.jpg     2019-11-03            [18, 10765]
# 3  /dXTyVDTIgeByvUOUEiHjbi8xX9A.jpg     2012-10-10  [80, 18, 9648, 10759]
# 7  /jEdce7g6VZHMoJ7DANX8NFQkVAW.jpg     2017-05-08                   [18]
# 2  /7r4FieFH6Eh6S55hi8c9LOiFENg.jpg     2015-08-23               [18, 27]
#
#       id                   name origin_country original_language  \
# 0   1622           Supernatural           [US]                en
# 1  68507     His Dark Materials           [GB]                en
# 3   1412                  Arrow           [US]                en
# 7  71641               4 Blocks           [DE]                de
# 2  62286  Fear the Walking Dead           [US]                en
#
#            original_name                                           overview  \
# ...
