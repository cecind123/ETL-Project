# %%
import pandas as pd 
import requests
from pprint import pprint
import NameDataModule as NDM
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d2f9c81eb93f> in <module>
#       2 import requests
#       3 from pprint import pprint
# ----> 4 import NameDataModule as NDM
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'NameDataModule'

# %%
df_BabyNames = pd.read_csv('Resources/most-popular-baby-names-2005-current-3.csv')

# %%
df_BabyNames
# Out:
#      YEAR  Gender  RANK       Name  Count
# 0    2005  Female     1      EMILY   3268
# 1    2005  Female     2     ASHLEY   2770
# 2    2005  Female     3   SAMANTHA   2483
# 3    2005  Female     4   ISABELLA   2333
# 4    2005  Female     5        MIA   2172
# 5    2005  Female     6    NATALIE   2035
# 6    2005  Female     7     SOPHIA   1876
# 7    2005  Female     8       EMMA   1626
# 8    2005  Female     9     ALYSSA   1612
# 9    2005  Female    10    MADISON   1523
# 10   2005  Female    11    JASMINE   1519
# 11   2005  Female    12  ELIZABETH   1479
# 12   2005  Female    13    JESSICA   1406
# 13   2005  Female    14   KIMBERLY   1397
# 14   2005  Female    15    ABIGAIL   1368
# 15   2005  Female    16    BRIANNA   1347
# 16   2005  Female    17   JENNIFER   1291
# 17   2005  Female    18        AVA   1223
# 18   2005  Female    19     HANNAH   1217
# 19   2005  Female    20      SARAH   1208
# 20   2005  Female    21     ALEXIS   1201
# 21   2005  Female    22     ANDREA   1197
# 22   2005  Female    23   ANGELINA   1175
# 23   2005  Female    24  STEPHANIE   1152
# 24   2005  Female    25    VANESSA   1151
# 25   2005    Male     1     DANIEL   3889
# 26   2005    Male     2    ANTHONY   3714
# 27   2005    Male     3      ANGEL   3538
# 28   2005    Male     4      DAVID   3243
# 29   2005    Male     5     JOSHUA   3203
# ..    ...     ...   ...        ...    ...
# 621  2017  Female    21      CHLOE    949
# 622  2017  Female    22        ZOE    886
# 623  2017  Female    23      GRACE    882
# 624  2017  Female    24   SAMANTHA    871
# 625  2017  Female    25    GENESIS    853
# 626  2017    Male     1       NOAH   2513
# 627  2017    Male     2  SEBASTIAN   2267
# 628  2017    Male     3       LIAM   2187
# 629  2017    Male     4      ETHAN   2147
# 630  2017    Male     5    MATTHEW   2132
# 631  2017    Male     6     DANIEL   2088
# 632  2017    Male     7      JACOB   2054
# 633  2017    Male     8      MATEO   2007
# 634  2017    Male     9  ALEXANDER   1998
# 635  2017    Male    10     JULIAN   1940
# 636  2017    Male    11   BENJAMIN   1850
# 637  2017    Male    12      LOGAN   1774
# 638  2017    Male    13     JAYDEN   1688
# 639  2017    Male    14      LUCAS   1633
# 640  2017    Male    15      AIDEN   1632
# 641  2017    Male    16     OLIVER   1561
# 642  2017    Male    17      DAVID   1553
# 643  2017    Male    18      AARON   1528
# 644  2017    Male    19     NATHAN   1518
# 645  2017    Male    20      DYLAN   1513
# 646  2017    Male    21      JAMES   1508
# 647  2017    Male    22    MICHAEL   1507
# 648  2017    Male    23     ELIJAH   1486
# 649  2017    Male    24    ANTHONY   1439
# 650  2017    Male    25      ISAAC   1423
#
# [651 rows x 5 columns]

# %%
df2 = df_BabyNames.groupby(["Name"]).sum()

# %%
df2
# Out:
#               YEAR  RANK  Count
# Name
# AARON        10071   110   7766
# ABIGAIL      26143   123  20081
# ADRIAN       20105   192  18777
# AIDEN        18117   138  16502
# ALEXA        16087   163   8533
# ALEXANDER    26143   100  32023
# ALEXIS        4014    45   2178
# ALLISON       4029    48   1800
# ALYSSA       14056    99   9106
# AMELIA        4033    33   2122
# ANDREA       12046   122   6835
# ANDREW       22110   106  26864
# ANGEL        22110   106  28529
# ANGELINA      4011    46   2331
# ANTHONY      26143    98  35013
# ARIA          6048    63   2961
# ASHLEY       16068    69  14971
# AUDREY        6039    67   2744
# AVA          26143   145  18568
# AVERY         4031    45   1878
# BELLA         2010    25    901
# BENJAMIN     14098   110  12528
# BRANDON      12045   131  11601
# BRIANNA      12045   102   7529
# CAMILA       20125   125  13921
# CHARLOTTE    12087    86   7172
# CHLOE        22132   188  12499
# CHRISTIAN    12045   131  11478
# CHRISTOPHER  16068   105  18906
# DANIEL       26143    34  39230
# ...            ...   ...    ...
# LOGAN         4031    37   3317
# LUCAS         4033    32   3261
# LUIS          6018    67   6043
# LUNA          2017    14   1150
# MADISON      24126   197  13926
# MASON        12081   115  10408
# MATEO         4033    20   3834
# MATTHEW      26143    95  32353
# MELANIE       6039    68   2678
# MIA          26143    51  30582
# MICHAEL      26143   170  28037
# MILA          2017    19   1052
# NATALIE      22110   114  17129
# NATHAN       26143   175  27854
# NOAH         22132   106  25964
# OLIVER        4033    39   3104
# OLIVIA       24138    98  22860
# PENELOPE      6048    50   3130
# RYAN          8026    90   8160
# SAMANTHA     26143   125  21472
# SARAH         4011    44   2360
# SCARLETT     10075    90   5049
# SEBASTIAN    10075    46  10250
# SOFIA        22132   112  18052
# SOPHIA       26143    35  36827
# STEPHANIE     2005    24   1152
# VALERIA       8033    73   4753
# VANESSA       6020    71   3382
# VICTORIA     22132   161  14510
# ZOE          14098   154   6434
#
# [94 rows x 3 columns]

# %%
sns.distplot( a=df2["Count"], hist=True, kde=True, rug=True )

# %%
sns.scatterplot(x="RANK", y="Count",data=df2)

# %%
sns.relplot(x="Name", y="Count",sizes=(40, 400), alpha=.5, palette="muted",height=6, data=df_BabyNames)

# %%
sns.lineplot(data=df_BabyNames,x="YEAR",y="Count",linewidth=2.5)

# %%
import plotly.express as px
#iris = px.data.iris()
fig = px.scatter_3d(df_BabyNames, x='Name', y='YEAR', z='Count', color='Count', symbol='Count')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9cfbe9e07ba2> in <module>
#       1 import plotly.express as px
#       2 #iris = px.data.iris()
# ----> 3 fig = px.scatter_3d(df_BabyNames, x='Name', y='YEAR', z='Count', color='Count', symbol='Count')
#       4 fig.show()
#
# NameError: name 'df_BabyNames' is not defined

# %%
import plotly.express as px
import plotly.express as px
fig = px.line_3d(df_BabyNames, x='Name', y='YEAR', z='Count',color="Name")
fig.show()
